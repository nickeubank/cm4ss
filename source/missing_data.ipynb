# %% [markdown]
# # Missing Data

# %% [markdown]
# NAs are a pain

# %%
NA == NA
# Out:
# [1] NA

# %%
NA == 4
# Out:
# [1] NA

# %%
4 + NA
# Out:
# [1] NA

# %%
is.na(NA)
# Out:
# [1] TRUE

# %%
!is.na(5)
# Out:
# [1] TRUE

# %%
mean(c(1, 2, 3, NA))
# Out:
# [1] NA

# %%
mean(c(1, 2, 3, NA), na.rm=TRUE)
# Out:
# [1] 2
